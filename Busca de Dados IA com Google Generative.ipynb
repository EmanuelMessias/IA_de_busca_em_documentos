# %% [markdown]
# <a href="https://colab.research.google.com/github/EmanuelMessias/IA_de_busca_em_documentos/blob/main/Busca%20de%20Dados%20IA%20com%20Google%20Generative.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -U -q google-generativeai

# %%
import numpy as np
import pandas as pd
import google.generativeai as genai

from google.colab import userdata
userdata.get('secretName')

GOOGLE_API_KEY = "AIzaSyDaaStxLKHT1BARcGlWIVkWjpx2Q_DK4pQ"
genai.configure(api_key=GOOGLE_API_KEY)

# %%
for m in genai.list_models():
  if "embedContent" in m.supported_generation_methods:
    print(m.name)
# Out:
# models/embedding-001
# models/text-embedding-004

# %%
#Embeddings
title = "A próxima geração de IA pra desenvolvedores e Google Workspace"
sample_text = ("Titulo: A próxima geração de IA pra desenvolvedores e Google Workspace"
    "\n"
    "Artigo Completo""\n"
    "Gemini API & Google AI Studio: Uma maneira acessível de criar e explorar protótipos de IA generativa"

)

embeddings = genai.embed_content(model="models/embedding-001",
                                content=sample_text,
                                 title=title,
                                 task_type="RETRIEVAL_DOCUMENT")

print(embeddings)
# Out:
# {'embedding': [0.045763507, -0.04330284, -0.022523697, 0.010413511, 0.06801919, -0.0051462254, -0.03210947, -0.018501762, 0.06288371, 0.05865091, 0.013104854, 0.026859032, -0.042243123, -0.023509607, 0.012695199, -0.021455273, 0.015725624, -0.013493001, -0.031826437, -0.0016639169, 0.008063786, 0.0075767245, -0.029531939, -0.06716793, -0.01432889, 0.021860793, 0.0107044475, -0.03676397, -0.031855147, 0.026157428, -0.047356732, 0.04857315, -0.03130803, 0.0103444075, -0.035354875, -0.042665485, -0.024674473, -0.0508488, 0.0024292094, 0.0035212543, 0.00968746, -0.08554414, -0.0077068335, 0.027566686, -0.0071080658, -0.030280804, 0.046918128, 0.038692284, 0.023354087, -0.05666706, 0.028832896, 0.01818196, 0.059913915, -0.042853937, -0.00881117, -0.0030632385, 0.02349293, -0.031054098, 0.03047052, 0.0057217996, 0.0014383578, 0.024078006, -0.021505708, 0.050186023, 0.017048834, -0.05403527, -0.04369961, -0.0033083255, 0.013626804, 0.047575776, 0.0119274575, 0.0071081338, 0.066193394, -0.06
# ...

# %%
#Documentos que serão buscados
DOCUMENT1 = {
  "Titulo": "Operação do Sistema de controle climático",
  "Conteúdo": "O Googlecar tem um sistema de controle climático que permite ajustar a temperatura e o controle de ar do carro."
}

DOCUMENT2 = {
  "Titulo": "Como usar o Google Maps",
  "Conteúdo": "O Google Maps é um serviço de mapeamento online que fornece imagens de mapas, visualização de ruas, condições de tráfego em tempo real e planejamento de rotas."
}

DOCUMENT3 = {
  "Titulo": "Benefícios do Google Assistente",
  "Conteúdo": "O Google Assistente é um assistente virtual que pode ajudá-lo com uma variedade de tarefas, incluindo fazer chamadas, enviar mensagens, definir alarmes e obter informações."
}

DOCUMENT4 = {
  "Titulo": "Segurança online para crianças",
  "Conteúdo": "É importante ensinar as crianças sobre segurança online, incluindo como identificar sites suspeitos, proteger suas informações pessoais e lidar com cyberbullying."
}

DOCUMENT5 = {
  "Titulo": "Os impactos da inteligência artificial",
  "Conteúdo": "A inteligência artificial está transformando rapidamente vários setores, desde saúde e finanças até transporte e educação."
}
DOCUMENT6 = {
  "Titulo": "Criptomoedas: O futuro do dinheiro?",
  "Conteúdo": "O Bitcoin e outras criptomoedas estão ganhando popularidade, mas seu futuro ainda é incerto."
}

DOCUMENT7 = {
  "Titulo": "Exploração espacial: A próxima fronteira",
  "Conteúdo": "Empresas privadas e agências governamentais estão investindo em missões para a Lua, Marte e além."
}

DOCUMENT8 = {
  "Titulo": "Energia renovável: O caminho a seguir",
  "Conteúdo": "A energia solar, eólica e outras fontes renováveis estão se tornando cada vez mais importantes para combater as mudanças climáticas."
}

DOCUMENT9 = {
  "Titulo": "A ética da inteligência artificial",
  "Conteúdo": "À medida que a IA se torna mais poderosa, é crucial considerar suas implicações éticas."
}

DOCUMENT10 = {
  "Titulo": "O metaverso: Realidade virtual e além",
  "Conteúdo": "O metaverso promete revolucionar a forma como interagimos com a tecnologia e uns com os outros."
}

DOCUMENT11 = {
  "Titulo": "Como criar um aplicativo",
  "Conteúdo": "Aprenda os fundamentos do desenvolvimento de aplicativos para Android e iOS."
}

DOCUMENT12 = {
  "Titulo": "Dicas para fotografia de paisagens",
  "Conteúdo": "Explore técnicas para capturar fotos de paisagens de tirar o fôlego."
}

DOCUMENT13 = {
  "Titulo": "Receitas vegetarianas fáceis",
  "Conteúdo": "Descubra deliciosas receitas vegetarianas que são simples de preparar."
}

DOCUMENT14 = {
  "Titulo": "Exercícios para iniciantes",
  "Conteúdo": "Comece sua jornada fitness com estes exercícios fáceis para iniciantes."
}

DOCUMENT15 = {
  "Titulo": "Meditação para redução do estresse",
  "Conteúdo": "Aprenda técnicas de meditação para acalmar a mente e reduzir o estresse."
}

DOCUMENT16 = {
  "Titulo": "História da música",
  "Conteúdo": "Explore a evolução da música através dos séculos."
}

DOCUMENT17 = {
  "Titulo": "Grandes obras da literatura",
  "Conteúdo": "Descubra clássicos da literatura de todo o mundo."
}

DOCUMENT18 = {
  "Titulo": "A arte da pintura",
  "Conteúdo": "Explore diferentes técnicas e estilos de pintura."
}

DOCUMENT19 = {
  "Titulo": "A dança como forma de expressão",
  "Conteúdo": "Aprenda sobre diferentes estilos de dança e sua história."
}

DOCUMENT20 = {
  "Titulo": "O teatro e suas origens",
  "Conteúdo": "Explore a história do teatro e sua importância cultural."
}

DOCUMENT21 = {
  "Titulo": "A filosofia da ciência",
  "Conteúdo": "Investigue os fundamentos e princípios da ciência."
}

DOCUMENT22 = {
  "Titulo": "A psicologia humana",
  "Conteúdo": "Explore a mente humana e seu comportamento."
}

DOCUMENT23 = {
  "Titulo": "A sociologia das comunidades",
  "Conteúdo": "Estude as interações sociais e a organização das sociedades."
}

DOCUMENT24 = {
  "Titulo": "Economia global",
  "Conteúdo": "Analise as tendências econômicas e desafios globais."
}

DOCUMENT25 = {
  "Titulo": "Política internacional",
  "Conteúdo": "Explore as relações entre países e organizações internacionais."
}

DOCUMENT26 = {
  "Titulo": "Direito e justiça",
  "Conteúdo": "Aprenda sobre os sistemas legais e princípios de justiça."
}

DOCUMENT27 = {
  "Titulo": "Educação e aprendizagem",
  "Conteúdo": "Explore diferentes abordagens e métodos de ensino."
}

DOCUMENT28 = {
  "Titulo": "Saúde e bem-estar",
  "Conteúdo": "Aprenda sobre como manter um estilo de vida saudável."
}

DOCUMENT29 = {
  "Titulo": "Viagens e turismo",
  "Conteúdo": "Explore destinos incríveis ao redor do mundo."
}

DOCUMENT30 = {
  "Titulo": "Culinária internacional",
  "Conteúdo": "Descubra sabores e pratos de diferentes culturas."
}
DOCUMENT31 = {
  "Titulo": "Navegação básica no cmd",
  "Conteúdo": """Comandos básicos para navegar entre pastas:
  - `cd`: Mudar de diretório.
  - `dir`: Listar arquivos e subdiretórios.
  - `cd ..`: Voltar para o diretório anterior.
  - `cd \`: Ir para a raiz do sistema."""
}

DOCUMENT32 = {
  "Titulo": "Manipulação de arquivos e pastas",
  "Conteúdo": """Gerenciando arquivos e pastas:
  - `mkdir`: Criar um novo diretório.
  - `rmdir`: Remover um diretório vazio.
  - `copy`: Copiar arquivos.
  - `move`: Mover arquivos ou renomeá-los.
  - `del`: Deletar arquivos."""
}

DOCUMENT33 = {
  "Titulo": "Gerenciamento de processos",
  "Conteúdo": """Interagindo com processos em execução:
  - `tasklist`: Mostrar a lista de processos em execução.
  - `taskkill`: Finalizar um processo específico pelo seu ID ou nome."""
}

DOCUMENT34 = {
  "Titulo": "Rede e Conectividade",
  "Conteúdo": """Comandos para gerenciar conexões de rede:
  - `ipconfig`: Exibir informações de configuração de rede.
  - `ping`: Testar a conectividade com um host remoto.
  - `netstat`: Mostrar estatísticas de rede e conexões ativas."""
}

DOCUMENT35 = {
  "Titulo": "Comandos do sistema",
  "Conteúdo": """Gerenciando o sistema operacional:
  - `systeminfo`: Obter informações detalhadas sobre o sistema.
  - `sfc /scannow`: Verificar e reparar arquivos de sistema corrompidos.
  - `chkdsk`: Verificar erros no disco rígido.
  - `shutdown`: Desligar ou reiniciar o computador."""
}

DOCUMENT36 = {
  "Titulo": "Trabalhando com texto",
  "Conteúdo": """Manipulando arquivos de texto:
  - `type`: Exibir o conteúdo de um arquivo de texto.
  - `find`: Procurar por texto específico em arquivos.
  - `more`: Exibir um arquivo de texto página por página."""
}

DOCUMENT37 = {
  "Titulo": "Scripts em Batch",
  "Conteúdo": """Automatizando tarefas com scripts:
  - Criar arquivos `.bat` com sequências de comandos.
  - Usar variáveis, loops e condicionais para lógica complexa.
  - Executar scripts no cmd para automatizar tarefas repetitivas."""
}

documents = [DOCUMENT1, DOCUMENT2, DOCUMENT3, DOCUMENT4, DOCUMENT5, DOCUMENT6, DOCUMENT7, DOCUMENT8, DOCUMENT9, DOCUMENT10,
             DOCUMENT11, DOCUMENT12, DOCUMENT13, DOCUMENT14, DOCUMENT15,
             DOCUMENT16, DOCUMENT17, DOCUMENT18, DOCUMENT19, DOCUMENT20,
             DOCUMENT21, DOCUMENT22, DOCUMENT23, DOCUMENT24, DOCUMENT25,
             DOCUMENT26, DOCUMENT27, DOCUMENT28, DOCUMENT29, DOCUMENT30, DOCUMENT31, DOCUMENT32, DOCUMENT33,
             DOCUMENT34, DOCUMENT35, DOCUMENT36, DOCUMENT37 ]

# %%
df = pd.DataFrame(documents)
df.columns = ["Titulo", "Conteudo"]
df
# Out:
#                                        Titulo  \
# 0   Operação do Sistema de controle climático
# 1                     Como usar o Google Maps
# 2             Benefícios do Google Assistente
# 3              Segurança online para crianças
# 4      Os impactos da inteligência artificial
# 5         Criptomoedas: O futuro do dinheiro?
# 6    Exploração espacial: A próxima fronteira
# 7       Energia renovável: O caminho a seguir
# 8          A ética da inteligência artificial
# 9       O metaverso: Realidade virtual e além
# 10                   Como criar um aplicativo
# 11         Dicas para fotografia de paisagens
# 12               Receitas vegetarianas fáceis
# 13                 Exercícios para iniciantes
# 14         Meditação para redução do estresse
# 15                         História da música
# 16                Grandes obras da literatura
# 17                          A arte da pintura
# 18            A dança como forma de expressão
# ...

# %%
model = "models/embedding-001"

# %%
def embed_fn(tittle,text):
  return genai.embed_content(model=model,
                                content=text,
                                 title=title,
                                 task_type="RETRIEVAL_DOCUMENT")["embedding"]

# %%
df["Embeddings"] = df.apply(lambda row: embed_fn(row["Titulo"], row["Conteudo"]), axis=1)
df
# Out:
#                                        Titulo  \
# 0   Operação do Sistema de controle climático
# 1                     Como usar o Google Maps
# 2             Benefícios do Google Assistente
# 3              Segurança online para crianças
# 4      Os impactos da inteligência artificial
# 5         Criptomoedas: O futuro do dinheiro?
# 6    Exploração espacial: A próxima fronteira
# 7       Energia renovável: O caminho a seguir
# 8          A ética da inteligência artificial
# 9       O metaverso: Realidade virtual e além
# 10                   Como criar um aplicativo
# 11         Dicas para fotografia de paisagens
# 12               Receitas vegetarianas fáceis
# 13                 Exercícios para iniciantes
# 14         Meditação para redução do estresse
# 15                         História da música
# 16                Grandes obras da literatura
# 17                          A arte da pintura
# 18            A dança como forma de expressão
# ...

# %%
def gerar_e_buscar_consulta(consulta, base, model):
  embedding_da_consulta = genai.embed_content(model=model,
                          content=consulta,
                          task_type="RETRIEVAL_QUERY")["embedding"]
  produtos_escalares = np.dot(np.stack(df["Embeddings"]), embedding_da_consulta)
  indice = np.argmax(produtos_escalares)
  return df.iloc[indice]["Conteudo"]

# %%
consulta = ""
trecho = gerar_e_buscar_consulta(consulta, df,model)
display(trecho)
# Out:
# 'Comandos básicos para navegar entre pastas:\n  - `cd`: Mudar de diretório.\n  - `dir`: Listar arquivos e subdiretórios.\n  - `cd ..`: Voltar para o diretório anterior.\n  - `cd \\`: Ir para a raiz do sistema.'
